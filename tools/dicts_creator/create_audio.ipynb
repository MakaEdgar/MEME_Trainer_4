# %%
p = """
cizinci
cizinky
cvičení
Jak se jmenujete?
je jako
je mi osmnáct let
jsem student medicíny
jsem z Egypta
jseš
jsme
jsou
jste
Kdo?
Kdy máme přestávku?
Kolik stojí jogurt?
Kolik to stojí?
Kolik?
lékař
lékaři
lékařka
lékařky
lekce
nejsem
Nejseš?
nejsme
nejsou
nejste
není
Odkud jseš?
Odkud jste?
Odkud?
příjmení
čelo
chytrý
cizí
dolní
horní
koleno
noha
nos
papír
peněženka
příklad
skříň
tělo
tužka
ucho
ústa
zdravý
odpoledne
rok devatenáct set osmdesát dva
rok dva tisíce deset
sto
sto jedna
v neděli
v pátek
v poledne
v pondělí
v sobotu
v úterý
v, ve
ve čtvrtek
ve středu
večer
zimní
kamarád
kamarádka
lidi
pravda
pravidelně
protože
restaurace
rodina
rozhovor
rozumět rozumím
sedět sedím
spát spím
trochu
učit se učím se
učit učím
v restauraci
vařit vařím
víkend
""".split("\n")

p = [x for x in p if x != ""]

# %%
n = """
572
450
1547
1641
1032
769
320
725
979
107
1741
307
1311
684
829
1710
904
207
186
1473
125
367
893
1519
1420
760
66
312
338
1457
1306
350
344
222
505
240
1110
721
889
1551
1357
40
1516
1676
1163
1642
776
557
990
25
1729
1621
683
17
1181
930
553
521
737
1077
915
1767
154
1556
863
924
1289
1460
1777
1087
1638
1139
1304
1229
1237
417
365
1322
1380
395
718
997
1719
""".split("\n")

n = [x for x in n if x != ""]

n = list(map(int, n))
n
# Out:
# [572,
#  450,
#  1547,
#  1641,
#  1032,
#  769,
#  320,
#  725,
#  979,
#  107,
#  1741,
#  307,
#  1311,
#  684,
#  829,
#  1710,
#  904,
#  207,
#  186,
#  1473,
#  125,
#  367,
#  893,
#  1519,
#  1420,
#  760,
#  66,
#  312,
#  338,
#  1457,
#  1306,
#  350,
#  344,
#  222,
#  505,
#  240,
#  1110,
#  721,
#  889,
#  1551,
#  1357,
#  40,
#  1516,
#  1676,
#  1163,
#  1642,
#  776,
#  557,
#  990,
#  25,
#  1729,
#  1621,
#  683,
#  17,
#  1181,
#  930,
#  553,
#  521,
#  737,
#  1077,
#  915,
#  1767,
#  154,
#  1556,
#  863,
#  924,
#  1289,
#  1460,
#  1777,
#  1087,
#  1638,
#  1139,
#  1304,
#  1229,
#  1237,
#  417,
#  365,
#  1322,
#  1380,
#  395,
#  718,
#  997,
#  1719]

# %%
dictname = "cz3_audio"

# %%
nums = !cd $dictname && ls
nums = list(map(int, nums))
nums
# Out:
# [0,
#  1,
#  10,
#  100,
#  1000,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  1009,
#  101,
#  1010,
#  1011,
#  1012,
#  1013,
#  1014,
#  1015,
#  1016,
#  1017,
#  1018,
#  1019,
#  102,
#  1020,
#  1021,
#  1022,
#  1023,
#  1024,
#  1025,
#  1026,
#  1027,
#  1028,
#  1029,
#  103,
#  1030,
#  1031,
#  1032,
#  1033,
#  1034,
#  1035,
#  1036,
#  1037,
#  1038,
#  1039,
#  104,
#  1040,
#  1041,
#  1042,
#  1043,
#  1044,
#  1045,
#  1046,
#  1047,
#  1048,
#  1049,
#  105,
#  1050,
#  1051,
#  1052,
#  1053,
#  1054,
#  1055,
#  1056,
#  1057,
#  1058,
#  1059,
#  106,
#  1060,
#  1061,
#  1062,
#  1063,
#  1064,
#  1065,
#  1066,
#  1067,
#  1068,
#  1069,
#  107,
#  1070,
#  1071,
#  1072,
#  1073,
#  1074,
#  1075,
#  1076,
#  1077,
#  1078,
#  1079,
#  108,
#  1080,
#  1081,
#  1082,
#  1083,
#  1084,
#  1085,
#  1086,
#  1087,
#  1088,
#  1089,
#  109,
#  1090,
#  1091,
#  1092,
#  1093,
#  1094,
#  1095,
#  1096,
#  1097,
#  1098,
#  1099,
# ...

# %%
import os

# %%
#os.rename("./czech1_audio/" + "wewe", "./czech1_audio/" + "we", )

# %%
for i in nums:
    if i not in n:
        os.remove(dictname + "/" + str(i))

# %%
for i in range(len(n)):
    os.rename("./" + dictname + "/" + str(n[i]),
              "./" + dictname + "/" + p[i].replace(" ", "_").replace(",", "_").replace(".", "_").replace("?", "") + ".mp3")
